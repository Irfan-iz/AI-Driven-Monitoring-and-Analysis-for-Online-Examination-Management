# %%
# --- Cell 1: Load Libraries and REAL Dataset ---
# %%time

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

print("Libraries imported.")

# --- Load the Data ---
# Make sure "Training_Essay_Data.csv" is in the same folder as this notebook
file_path = "Training_Essay_Data.csv" 

print(f"Loading data from {file_path}...")
try:
    df = pd.read_csv(file_path)

    # --- Explore the Data ---
    print(f"Data loaded successfully. Total essays: {len(df)}")
    
    # .head() shows the first 5 rows
    print("\n--- Data Head ---")
    print(df.head())
    
    # .value_counts() shows how many Human vs. AI labels we have
    # This is the "label" column from the Kaggle dataset
    print("\n--- Label Distribution ---")
    print(df['generated'].value_counts())

except FileNotFoundError:
    print("---!!! ERROR !!!---")
    print(f"File not found: {file_path}")
    print("Please make sure you downloaded the Kaggle file and placed it in the same folder as this notebook.")
# Out:
# UsageError: Line magic function `%%time` not found.
